# %% [markdown]
# #GOAL

# %% [markdown]
# # PACKAGES

# %%
# !pip install git+git://github.com/govex/talentpy
from talentpy import Talent
# Out:
# ...
#   Cloning git://github.com/govex/talentpy to /tmp/pip-req-build-rxaeh8rt
#   Running command git clone -q git://github.com/govex/talentpy /tmp/pip-req-build-rxaeh8rt
# ...
#   Created wheel for talentpy: filename=talentpy-0.1-cp37-none-any.whl size=2984 sha256=843f626dba80e017e88b992b85c3504a092519350064ec379835f05397c3cd10
#   Stored in directory: /tmp/pip-ephem-wheel-cache-faih8sjs/wheels/fd/31/fb/9fe3252951e8919eb09f8aff5308ce4648a4b5ea15492b0ec2
# Successfully built talentpy
# ...

# %%
import requests

# %% [markdown]
# #PARAMETERS

# %%
apikey="jFqqk4Exl21bgvnwDtriPyd52D4bgy"
domain="humane.talentlms.com"

# %% [markdown]
# # FUNCTION

# %% [markdown]
# # DATA WRANGLING

# %%
t = Talent(apikey=apikey, domain=domain)

# %%
t.get_courses()
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     342         try:
# --> 343             self._validate_conn(conn)
#     344         except (SocketTimeout, BaseSSLError) as e:
#
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
# ...

# %% [markdown]
# # CONCLUSIONS
# - Impossible to use the package. It raises an error about site certification.
